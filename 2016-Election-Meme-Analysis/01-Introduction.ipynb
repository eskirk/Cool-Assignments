# %% [markdown]
# ![Image of Yaktocat](./terrible_memes/memes.png)
# > jesus christ why am I doing my final project on memes

# %% [markdown]
# # <center>Why memes?
# > Lets start with a definition: A meme, as it was originally defined:
# >><b>"an idea, behavior, or style that spreads from person to person within a culture"</b>
#
# > Like it or not, with the increased connectivity due to the internet, memes are now more powerful than they
# > have ever been.
#
# > It started with DJ Khaled, he made a meme of himself and skyrocked in popularity simply by acting silly and abusing
# > the magical meme wizardry of social media. He is now his own brand, all because of <i>meme magic</i>.
#
# > Taking this one step further is Donald Trump. Knowingly or not, Donald Trump made himself a meme by being the
# > <b>most absurd</b>, serious political candidate the United States has ever seen.
# > he skyrocketed in popularity because, like him or not, people could not stop talking about him and his ideology
# > spread like wildfire.
#
# ## <center>absolute absurd <font color='pink'><i>meme magic</i>

# %% [markdown]
# # <center>So what kind of <font color='brown'>low quality, </font><font color='teal'>trash tier content</font> are we dealing with here?</center>
# # <center>The <font color='brown'>worst</font> kind of meme imaginable</center>

# %% [markdown]
# ![Image of Yaktocat](./terrible_memes/political_memes.png)

# %% [markdown]
# # <center>The Dataset</center>
#
# > This dataset came from kaggle. It was the [2016 U.S. Election Memes](https://www.kaggle.com/SIZZLE/2016electionmemes) dataset.
#
# > It contains memes from all of the candidates from the 2016 election cycle. I narrowed it down to just Hillary Clinton, Bernie Sanders, and Donald Trump.

# %%
from IPython.display import Image
from IPython.display import display
import pandas as pd

all_memes = pd.read_csv('../../../data/eskirk/data/all_memes.csv')
all_memes.drop('Unnamed: 0', axis = 1)
# Out:
#             timestamp                                               link  \
# 0        8/1/16 20:56                           http://imgur.com/a/lNHED
# 1        9/5/16 13:51                           http://imgur.com/a/Cm6ls
# 2        7/27/16 0:54                           http://imgur.com/a/FRGrq
# 3         7/8/16 4:12                           http://imgur.com/a/zF2Bw
# 4       10/20/16 7:34                           http://imgur.com/a/giimL
# 5       10/22/16 5:10                           http://imgur.com/a/tPNT6
# 6       9/24/16 21:13                           http://imgur.com/6wA1BRb
# 7       7/26/16 19:45                           http://imgur.com/a/R5Iqq
# 8      10/20/16 13:15                           http://imgur.com/tz9ej1D
# 9        6/8/16 18:43                           http://imgur.com/IpprlC4
# 10      10/26/16 2:30                           http://imgur.com/a/e6gme
# 11      9/22/16 19:50                           http://imgur.com/DhJrWNL
# ...

# %% [markdown]
# # <center>What kind of questions am I interested in here?</center>
# > - Where do most of these memes come from and which candidate was most successful in the meme economy?
#
# > - Is there anything interesting to note about the content of these memes?
#
# > - Are there any common traits amongst memes describing each candidate?

# %% [markdown]
# # <center>What do these memes even look like? Are they <font color='pink'><i>quality memes?</i>
#
# ###### <center><i>there is no such thing

# %%
Image('./terrible_memes/meme1.jpg')

# %%
Image('./terrible_memes/meme2.jpg')

# %%
Image('./terrible_memes/meme3.png')

# %%
Image('./terrible_memes/meme4.png')

# %% [markdown]
# # [02-Analysis](02-Analysis.ipynb)
