# %% [markdown]
# # <center>The Data

# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline
from IPython.display import Image, display
from IPython.core.display import HTML

# %%
path = '../../../data/eskirk/data/'
files = !ls ../../../data/eskirk/data
pd.DataFrame(files[:6])
# Out:
#              0
# 0     Bern.csv
# 1   Bernie.csv
# 2  Clinton.csv
# 3   Donald.csv
# 4  Hillary.csv
# 5    Trump.csv

# %% [markdown]
# # <center>Parsing the Files

# %%
bern = pd.read_csv(path + files[0], encoding = 'ISO-8859-1', sep = ',', low_memory=True)
bernie = pd.read_csv(path + files[1], encoding = 'ISO-8859-1', sep = ',', low_memory=True)
clinton = pd.read_csv(path + files[2], encoding = 'ISO-8859-1', sep = ',', low_memory=True)
trump = pd.read_csv(path + files[3], encoding = 'ISO-8859-1', sep = ',', low_memory=True)
hillary = pd.read_csv(path + files[4], encoding = 'ISO-8859-1', sep = ',', low_memory=False)
donald = pd.read_csv(path + files[5], encoding = 'ISO-8859-1', sep = ',', low_memory=True)
# Out:
# /opt/conda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (198) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
columns = ['timestamp', 'link', 'caption', 'network', 'likes']

trump = trump[columns]
donald = donald[columns]
bernie = bernie[columns]
bern = bern[columns]
clinton = clinton[columns]
hillary = hillary[columns]

# %% [markdown]
# # <center>Tidying the Data

# %%
clinton_memes = pd.concat([hillary, clinton])
clinton_memes['candidate'] = 'clinton'

sanders_memes = pd.concat([bernie, bern])
sanders_memes['candidate'] = 'sanders'

trump_memes = pd.concat([donald, trump])
trump_memes['candidate'] = 'trump'

# %%
capts1 = clinton_memes['caption']
capts1 = [c.replace('\\n', ' ') for c in capts1]
capts2 = sanders_memes['caption']
capts2 = [c.replace('\\n', ' ') for c in capts2]
capts3 = trump_memes['caption']
capts3 = [c.replace('\\n', ' ') for c in capts3]

clinton_memes['caption'] = capts1
sanders_memes['caption'] = capts2
trump_memes['caption'] = capts3

# %%
all_memes = pd.concat([clinton_memes, sanders_memes, trump_memes]).drop_duplicates()
memes_and_likes = all_memes[['likes', 'candidate', 'network']]
all_memes.shape
# Out:
# (35382, 6)

# %%
assert all_memes.likes.dtype == 'int64'
assert all_memes.candidate.dtype == 'O'
assert all_memes.network.dtype == 'O'
assert all_memes.caption.dtype == 'O'

# %% [markdown]
# # <center>The Clean DataFrame

# %%
all_memes
# Out:
#            timestamp                                               link  \
# 0       8/1/16 20:56                           http://imgur.com/a/lNHED
# 1       9/5/16 13:51                           http://imgur.com/a/Cm6ls
# 2       7/27/16 0:54                           http://imgur.com/a/FRGrq
# 3        7/8/16 4:12                           http://imgur.com/a/zF2Bw
# 4      10/20/16 7:34                           http://imgur.com/a/giimL
# 5      10/22/16 5:10                           http://imgur.com/a/tPNT6
# 6      9/24/16 21:13                           http://imgur.com/6wA1BRb
# 7      7/26/16 19:45                           http://imgur.com/a/R5Iqq
# 8     10/20/16 13:15                           http://imgur.com/tz9ej1D
# 9       6/8/16 18:43                           http://imgur.com/IpprlC4
# 10     10/26/16 2:30                           http://imgur.com/a/e6gme
# 8250   10/20/16 1:17                https://instagram.com/p/BLxBe26hFws
# 8253  10/14/16 14:46  https://facebook.com/346937065399354/posts/127...
# 8262   1/30/16 16:10                https://instagram.com/p/BBK1yMuGokG
# 8270    4/13/16 3:24                https://instagram.com/p/BEIA-T1lXh3
#
#                                                 caption    network   likes  \
# 0     Son killed by  country, in a  in a  war starte...      imgur     -20
# 1     TRUMP LOVES TRUMP, AND  DOES WHAT HIS FOLLOWER...      imgur     -17
# 2     1h  Why end racism when we can just  end the c...      imgur     -16
# 3     Do jokes about not noticing someone  because t...      imgur     -16
# 4     HILLARY CLINTON SAYS YOU CAN  KILL A BABY THE ...      imgur     -14
# 5     I Liked  p Message Save  More  A Write a comme...      imgur     -13
# 6     Hillary couldn't even take care of her husband...      imgur     -12
# 7     Yesterday at 09:15.  There will never be a con...      imgur     -12
# 8     LIVE  LIVE  DOVALLO TRE IS HILLARY (Al ATO  Su...      imgur     -11
# 9     AMI THE ONY ONE  THAT REALIZES WHAT WILL HAPPE...      imgur     -11
# 10    This is such a hypocritical thing to be on hil...      imgur     -10
# 11    MEN YOU HEAR HILLARY S HEALTH IS  FADING  MONE...      imgur     -10
# 12    "There's this leaked email. if  you see it, yo...      imgur      -9
# 13    feeling Creeped out!  Yesterday at 9:10 PM  So...      imgur      -9
# 14    4.32pm: ARF ARF ARF  4.58pm: Crooked  Hillary....      imgur      -9
# 15    Me & Moe  AM Radio  Show  I have what it takes...      imgur      -9
# 16    Bernie or Hillary?  Be informed. Compare them ...      imgur      -9
# 17    The tide of terror that swept America IS HERE ...      imgur      -8
# 18    TORCHIC  Lw5  17/ 20  The wild Hillary has fai...      imgur      -8
# 19    photo  shared  4 hrs  BACK TO 1946  IEEDIT!  F...      imgur      -7
# 20    what if h3h3 was black?  #Project Murphy   pro...      imgur      -7
# 21    "IT's GETTING WORSE  Afolo blasto CAANIE GORki...      imgur      -6
# 22    AWrapUp This Year SEIection  Yes, Madam  Secre...      imgur      -6
# 23    Kind Trump supporters. by Receiverstud in poli...      imgur      -6
# 24    6:26 PM  89%  ..ooo Verizon  Search  Replies t...      imgur      -5
# 25    shared occupy Democrats Logic's photo  11 hrs ...      imgur      -5
# 26    Yes, we elected a nationalistic, anti-immigran...      imgur      -5
# 27    12:50 AM  65%  ooooo Sprint  Messages  MR  Det...      imgur      -4
# 28                              HILLARY FOR PRISM  2016      imgur      -4
# 29    2507  Hillary is speaking about vets today. He...      imgur      -4
# ...                                                 ...        ...     ...
# 8141                DONALD TRUMP  hotfuzs  Holy trinity  instagram   22449
# 8147  Always wondered too  You know whats weird  Don...  instagram   23836
# 8149  HITLER'  +If you  AMERICA  like  ORE  BILL The...  instagram   24694
# 8156  MAK A ME  TRU M P  www.Donald ITrump.com  MAKE...  instagram   26279
# 8158  Donald Trump  says the  Hillary Clinton  scand...   facebook   26551
# 8160  A new billboard in Dearborn, Michigan  says in...   facebook   26646
# 8163  Donald Trump  DJ Khaled  VS  -A clearly superi...  instagram   27048
# 8164  I am much more concerned  about what Hillary C...   facebook   27106
# 8170  DEAR REPUBLICANS.  WOULD YOU LEAVE DONALD TRUM...   facebook   28203
# 8180  George Takei  George Takei  As Commander-in-Ch...   facebook   32500
# 8181  have a dream  have a dram  that  Donald toymp ...  instagram   32823
# 8186  TO ACT LIKE WHAT I  DONALD TRUMP  SAIDIS SO FA...  instagram   34202
# 8188  BILLY BUSH WAS FORCED TO LEAVE THE  TODAY SHOW...   facebook   36070
# 8193    "Donald Please Just Answer The Question  Donald  instagram   37187
# 8196  Justin Bieber wants to be Donald Trump  so bad...  instagram   39511
# 8202  DON'T DO IT DONALD!  DON'T YOU DARE.  ADAM ELL...   facebook   41085
# 8205  Metro Boomin  @MetroBoomin  i dont trust donal...  instagram   42235
# 8208                        NEWS  N-ONE WITH DONALD TRU  instagram   43911
# 8209  b/r  MAG  20 OF  22 21 OF  21  BLACK NFL PLAYE...  instagram   45019
# 8213  ADOLF HITLER  Used racism to rise  to power  P...   facebook   46341
# 8218  occupy Democrats  Donald Trump  dodged the dra...   facebook   50162
# 8228  why Donald Trumps daughter look like  Sid from...  instagram   55542
# 8230  SIX AMERICANS JUST  WON THE NOBEL PRIZE  FOR 2...   facebook   58387
# 8233  Donald Trump  DJ Khaled  VS  -A early superior...  instagram   59157
# 8236  BREAKING NEWS: If you face-swap  @real Donald ...  instagram   61907
# 8244  Voting against  Donald Trump  will  be the mos...   facebook   67297
# 8250  Elliot Tebele  Fuck Jerry  Donald and Hillary ...  instagram   81830
# 8253  "DONALD TRUMP  SAYS IT WAS JUST  LOCKER-ROOM T...   facebook   92697
# 8262  This 3rd grader is going places  have a dream ...  instagram  138015
# 8270  Barack Obama  barackobama  Instead of building...  instagram  236835
#
#      candidate
# 0      clinton
# 1      clinton
# 2      clinton
# 3      clinton
# 4      clinton
# 5      clinton
# 6      clinton
# 7      clinton
# 8      clinton
# 9      clinton
# 10     clinton
# 11     clinton
# 12     clinton
# 13     clinton
# 14     clinton
# 15     clinton
# 16     clinton
# 17     clinton
# 18     clinton
# 19     clinton
# 20     clinton
# 21     clinton
# 22     clinton
# 23     clinton
# 24     clinton
# 25     clinton
# 26     clinton
# 27     clinton
# 28     clinton
# 29     clinton
# ...        ...
# 8141     trump
# 8147     trump
# 8149     trump
# 8156     trump
# 8158     trump
# 8160     trump
# 8163     trump
# 8164     trump
# 8170     trump
# 8180     trump
# 8181     trump
# 8186     trump
# 8188     trump
# 8193     trump
# 8196     trump
# 8202     trump
# 8205     trump
# 8208     trump
# 8209     trump
# 8213     trump
# 8218     trump
# 8228     trump
# 8230     trump
# 8233     trump
# 8236     trump
# 8244     trump
# 8250     trump
# 8253     trump
# 8262     trump
# 8270     trump
#
# [35382 rows x 6 columns]

# %% [markdown]
# # <center>Create Dummies for Classification

# %%
networks = list(all_memes['network'].unique())
networks
# Out:
# ['imgur', 'facebook', 'instagram', 'twitter']

# %%
network = all_memes['network']
candidate = all_memes['candidate']

network_dummie = pd.get_dummies(network, prefix='network')
candidate_dummie = pd.get_dummies(candidate, prefix='candidate')

# %%
candidate_dummie = candidate_dummie[['candidate_clinton', 'candidate_trump']]
network_dummie = network_dummie[['network_instagram', 'network_twitter', 'network_facebook']]
all_memes = pd.concat([all_memes, network_dummie, candidate_dummie], axis=1)
all_memes
# Out:
#            timestamp                                               link  \
# 0       8/1/16 20:56                           http://imgur.com/a/lNHED
# 1       9/5/16 13:51                           http://imgur.com/a/Cm6ls
# 2       7/27/16 0:54                           http://imgur.com/a/FRGrq
# 3        7/8/16 4:12                           http://imgur.com/a/zF2Bw
# 4      10/20/16 7:34                           http://imgur.com/a/giimL
# 5      10/22/16 5:10                           http://imgur.com/a/tPNT6
# 6      9/24/16 21:13                           http://imgur.com/6wA1BRb
# 7      7/26/16 19:45                           http://imgur.com/a/R5Iqq
# 8     10/20/16 13:15                           http://imgur.com/tz9ej1D
# 9       6/8/16 18:43                           http://imgur.com/IpprlC4
# 10     10/26/16 2:30                           http://imgur.com/a/e6gme
# 11     9/22/16 19:50                           http://imgur.com/DhJrWNL
# 12     10/29/16 3:16                           http://imgur.com/a/a2IsC
# 13    10/26/16 12:55                           http://imgur.com/a/O1jJ6
# 14      6/10/16 0:22                           http://imgur.com/vVaQn77
# 15      5/7/16 14:05                           http://imgur.com/pvgPelF
# 16      2/26/16 7:31                           http://imgur.com/TbOyNzW
# 17    10/27/16 14:35                           http://imgur.com/rTRPxrH
# 18      9/13/16 7:03                           http://imgur.com/a/C0iaM
# 19     10/15/16 4:09                           http://imgur.com/a/maTtU
# 20      4/30/16 4:28                             http://imgur.com/GhUli
# 21       8/5/16 4:43                           http://imgur.com/a/8hZaB
# 22     7/25/16 18:53                           http://imgur.com/a/8Gx9B
# 23     5/10/16 20:24                           http://imgur.com/SebZnol
# 24     10/12/16 1:02                           http://imgur.com/a/YqWdX
# 25     9/30/16 14:07                           http://imgur.com/a/jVJix
# 26      7/28/16 1:42                           http://imgur.com/a/VTqys
# 27     10/20/16 5:56                           http://imgur.com/a/WsD4h
# 28      9/29/16 7:12                           http://imgur.com/a/l5Y6m
# 29     7/25/16 22:26                           http://imgur.com/a/Dfzwy
# ...              ...                                                ...
# 8141   10/28/16 0:46                https://instagram.com/p/BMFkU6Hj1iO
# 8147   3/14/15 11:36                 https://instagram.com/p/0NOjcnmonC
# 8149    4/3/16 20:09                https://instagram.com/p/BDwEE7fmZFx
# 8156    7/16/15 2:32                 https://instagram.com/p/5LiyOkHgYt
# 8158  10/21/16 10:40  https://facebook.com/226821494115353/posts/957...
# 8160   10/18/16 4:51  https://facebook.com/1645816202305254/posts/18...
# 8163   12/17/15 2:50                 https://instagram.com/p/_YHRlrHgZX
# 8164   10/15/16 5:34  https://facebook.com/226821494115353/posts/952...
# 8170   10/9/16 22:18  https://facebook.com/346937065399354/posts/126...
# 8180   9/19/16 20:22  https://facebook.com/205344452828349/posts/168...
# 8181   1/30/16 23:42                https://instagram.com/p/BBLpnOangVr
# 8186  10/14/16 17:29                https://instagram.com/p/BLjT9-vjqo-
# 8188   10/18/16 0:32  https://facebook.com/346937065399354/posts/127...
# 8193   10/10/16 3:42                https://instagram.com/p/BLXiJ2IhWQs
# 8196    9/11/15 1:39                 https://instagram.com/p/7eOEs_AH7K
# 8202   9/29/16 21:10  https://facebook.com/136450789739469/posts/128...
# 8205    3/3/16 19:37                https://instagram.com/p/BCgL0FIngb9
# 8208   12/29/15 6:02                 https://instagram.com/p/_3W1nPHgSO
# 8209   10/5/16 17:00                https://instagram.com/p/BLMFcW2Dxco
# 8213  10/13/16 10:59  https://facebook.com/346937065399354/posts/126...
# 8218   10/18/16 1:28  https://facebook.com/346937065399354/posts/127...
# 8228    3/30/16 7:34                https://instagram.com/p/BDkaffGDbP0
# 8230  10/10/16 23:26  https://facebook.com/346937065399354/posts/126...
# 8233   12/17/15 3:41                 https://instagram.com/p/_YNHgNgH5L
# 8236   6/24/16 14:11                https://instagram.com/p/BHCkUqbBVHp
# 8244  10/16/16 16:47  https://facebook.com/346937065399354/posts/127...
# 8250   10/20/16 1:17                https://instagram.com/p/BLxBe26hFws
# 8253  10/14/16 14:46  https://facebook.com/346937065399354/posts/127...
# 8262   1/30/16 16:10                https://instagram.com/p/BBK1yMuGokG
# 8270    4/13/16 3:24                https://instagram.com/p/BEIA-T1lXh3
#
#                                                 caption    network   likes  \
# 0     Son killed by  country, in a  in a  war starte...      imgur     -20
# 1     TRUMP LOVES TRUMP, AND  DOES WHAT HIS FOLLOWER...      imgur     -17
# 2     1h  Why end racism when we can just  end the c...      imgur     -16
# 3     Do jokes about not noticing someone  because t...      imgur     -16
# 4     HILLARY CLINTON SAYS YOU CAN  KILL A BABY THE ...      imgur     -14
# 5     I Liked  p Message Save  More  A Write a comme...      imgur     -13
# 6     Hillary couldn't even take care of her husband...      imgur     -12
# 7     Yesterday at 09:15.  There will never be a con...      imgur     -12
# 8     LIVE  LIVE  DOVALLO TRE IS HILLARY (Al ATO  Su...      imgur     -11
# 9     AMI THE ONY ONE  THAT REALIZES WHAT WILL HAPPE...      imgur     -11
# 10    This is such a hypocritical thing to be on hil...      imgur     -10
# 11    MEN YOU HEAR HILLARY S HEALTH IS  FADING  MONE...      imgur     -10
# 12    "There's this leaked email. if  you see it, yo...      imgur      -9
# 13    feeling Creeped out!  Yesterday at 9:10 PM  So...      imgur      -9
# 14    4.32pm: ARF ARF ARF  4.58pm: Crooked  Hillary....      imgur      -9
# 15    Me & Moe  AM Radio  Show  I have what it takes...      imgur      -9
# 16    Bernie or Hillary?  Be informed. Compare them ...      imgur      -9
# 17    The tide of terror that swept America IS HERE ...      imgur      -8
# 18    TORCHIC  Lw5  17/ 20  The wild Hillary has fai...      imgur      -8
# 19    photo  shared  4 hrs  BACK TO 1946  IEEDIT!  F...      imgur      -7
# 20    what if h3h3 was black?  #Project Murphy   pro...      imgur      -7
# 21    "IT's GETTING WORSE  Afolo blasto CAANIE GORki...      imgur      -6
lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# >Split the data for two different training and testing sets, one for the network and one for the candidate.

# %%
# Network training and testing sets
# commented out for presentation

# Xn_train, Xn_test, yn_train, yn_test = train_test_split(captions, network, test_size = 0.3)

# Candidate training and testing sets
# Xc_train, Xc_test, yc_train, yc_test = train_test_split(captions, candidate, test_size = 0.3)

# %%
# np.save(file = 'terrible_memes/Xc_train', arr = Xc_train)
# np.save(file = 'terrible_memes/yc_train', arr = yc_train)
# np.save(file = 'terrible_memes/Xn_train', arr = Xn_train)
# np.save(file = 'terrible_memes/yn_train', arr = yn_train)

# np.save(file = 'terrible_memes/Xc_test', arr = Xc_test)
# np.save(file = 'terrible_memes/yc_test', arr = yc_test)
# np.save(file = 'terrible_memes/Xn_test', arr = Xn_test)
# np.save(file = 'terrible_memes/yn_test', arr = yn_test)

# %%
Xn_train = np.load(file = 'terrible_memes/Xn_train.npy')
yn_train = np.load(file = 'terrible_memes/yn_train.npy')
Xc_train = np.load(file = 'terrible_memes/Xc_train.npy')
yc_train = np.load(file = 'terrible_memes/yc_train.npy')
Xc_test = np.load(file = 'terrible_memes/Xc_test.npy')
yc_test = np.load(file = 'terrible_memes/yc_test.npy')
Xn_test = np.load(file = 'terrible_memes/Xn_test.npy')
yn_test = np.load(file = 'terrible_memes/yn_test.npy')

Xn_train = pd.Series(Xn_train)
yn_train = pd.Series(yn_train)
Xc_train = pd.Series(Xc_train)
yc_train = pd.Series(yc_train)
Xc_test = pd.Series(Xc_test)
yc_test = pd.Series(yc_test)
Xn_test = pd.Series(Xn_test)
yn_test = pd.Series(yn_test)

# %% [markdown]
# # <center>Create a Pipeline for the Model
# > For this model, I will be using a TF-IDF to analyze the text and a pipeline that attaches it to a random forest classifier

# %%
# network_forest_model = make_pipeline(TfidfVectorizer(lowercase=True), 
#                                      RandomForestClassifier(class_weight='balanced'))

# candidate_forest_model = make_pipeline(TfidfVectorizer(lowercase=True, analyzer='word'), 
#                                        RandomForestClassifier(class_weight='balanced', 
#                                        random_state=0))

# %% [markdown]
# > Fit the candidate and network models to the data

# %%
# as exciting as it is to wait 3 minutes to fit the data to my model, let's skip over that

# network_forest_model.fit(Xn_train, yn_train)
# candidate_forest_model.fit_transform(Xc_train, yc_train)

# %% [markdown]
# > Load the previously saved models (fitting the models takes a loooong time)

# %%
from sklearn.externals import joblib

# save the model to a file
# joblib.dump(candidate_forest_model, 'terrible_memes/candidate.pkl') 
# joblib.dump(network_forest_model, 'terrible_memes/network.pkl')

# %%
candidate_forest_model = joblib.load('terrible_memes/candidate.pkl')
network_forest_model = joblib.load('terrible_memes/network.pkl')

# %% [markdown]
# # <center>Categorize the Test Data

# %%
yc_forest_predict = candidate_forest_model.predict(Xc_test)
print('I can predict the candidate with an accuracy of:\n', accuracy_score(yc_test, yc_forest_predict))
# Out:
# I can predict the candidate with an accuracy of:
#  0.773339613754

# %%
yn_predict = network_forest_model.predict(Xn_test)
print('I can predict the network with an accuracy of:\n', accuracy_score(yn_test, yn_predict))
# Out:
# I can predict the network with an accuracy of:
#  0.766462552991

# %% [markdown]
# > What exactly is the output here?

# %%
pd.DataFrame(yc_forest_predict).head(10)
# Out:
#          0
# 0    trump
# 1    trump
# 2  clinton
# 3    trump
# 4  sanders
# 5  clinton
# 6    trump
# 7    trump
# 8    trump
# 9    trump

# %%
pd.DataFrame(yc_test).head(10)
# Out:
#          0
# 0    trump
# 1    trump
# 2  clinton
# 3    trump
# 4  sanders
# 5  clinton
# 6    trump
# 7    trump
# 8    trump
# 9    trump

# %% [markdown]
# # <center>Candidate Feature Importances

# %% [markdown]
# > Now comes the interesting part

# %%
from operator import itemgetter

importance = candidate_forest_model.named_steps['randomforestclassifier'].feature_importances_
feats = candidate_forest_model.named_steps['tfidfvectorizer'].get_feature_names()
vocab = candidate_forest_model.named_steps['tfidfvectorizer'].vocabulary_
important_features = zip(feats, importance)

candidate_importances = list(reversed((list(sorted(important_features, key=itemgetter(1))))))

# %% [markdown]
# > Network Feature Importances

# %%
ntwrk_importance = network_forest_model.named_steps['randomforestclassifier'].feature_importances_
ntwrk_feats = network_forest_model.named_steps['tfidfvectorizer'].get_feature_names()
ntwrk_vocab = network_forest_model.named_steps['tfidfvectorizer'].vocabulary_
ntwrk_important_features = zip(ntwrk_feats, ntwrk_importance)

network_importances = list(reversed((list(sorted(ntwrk_important_features, key=itemgetter(1))))))

# %% [markdown]
# > Importance of Features per Candidate

# %%
phrase = ['clinton', 'trump', 'bird', 'make america great again', 'her emails']
vectorized = candidate_forest_model.named_steps['tfidfvectorizer'].transform(phrase)
classes = candidate_forest_model.named_steps['randomforestclassifier'].classes_
probs = candidate_forest_model.named_steps['randomforestclassifier'].predict_proba(vectorized)
print(classes, '\n', probs)
# Out:
# ['clinton' 'sanders' 'trump']
#  [[ 1.   0.   0. ]
#  [ 0.   0.   1. ]
#  [ 0.3  0.4  0.3]
#  [ 0.   0.   1. ]
#  [ 0.7  0.2  0.1]]

# %%
df = pd.DataFrame(network_importances)
df.columns = ['phrase', 'importance']
df.head(10)
# Out:
#     phrase  importance
# 0    trump    0.017002
# 1   donald    0.011886
# 2  hillary    0.009592
# 3  clinton    0.008638
# 4      the    0.008583
# 5       to    0.005763
# 6       on    0.005407
# 7      you    0.005343
# 8      for    0.005303
# 9     when    0.004893

# %%
df2 = pd.DataFrame(candidate_importances)
df2.columns = ['phrase', 'importance']
df2.head(10)
# Out:
#     phrase  importance
# 0   bernie    0.109171
# 1  hillary    0.062727
# 2    trump    0.052319
# 3  clinton    0.044384
# 4   donald    0.031546
# 5  sanders    0.014464
# 6     bern    0.008739
# 7   matter    0.008017
# 8      the    0.005300
# 9  compare    0.005190

# %% [markdown]
# # [03-Visualizations](03-Visualizations.ipynb)
